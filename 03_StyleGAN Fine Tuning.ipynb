# %% [markdown]
# # Image Re-sizing for GAN fine tuning
#
# **NOTE**: This notebook consists of two parts.  Image Selection for the GAN fine tuning can be run locally in order to resize for GAN consumption, but the images will need to be uploaded into Google Collab for the second half.  Using StyleGAN to generate images requires GPUs, and it is recommended to run in Google Collab to speed up should be the fine-tuning process.

# %%
# Import libraries used in the image re-sizing portion of the notebook
import os
import cv2
import numpy as np
import pandas as pd
import random
from matplotlib import pyplot as plt
from PIL import Image
from pathlib import Path

# %%
# Set File path for Image Data
data_filepath = './data/chest_xray'

# %%
# Create a Dataframe of image paths and their corresponding Label (Normal, Pnemonia)

# Use the TRAIN and TEST directories to build Dataframe
image_dirs = ['train', 'test', 'val']
data = []

# Loop through Image Directories to find images
for dir in image_dirs:
    dir_path = os.path.join(data_filepath, dir)
    # Loop through NORMAL and PNEUMONIA directories, and label images accordingly
    for label_name in ["NORMAL", "PNEUMONIA"]:
        label_dir = os.path.join(dir_path, label_name)
        for file_name in os.listdir(label_dir):
            file_path = os.path.join(label_dir, file_name)
            # Ensure it's an image file (basic check)
            if file_name.endswith(('.png', '.jpg', '.jpeg')):
                data.append([dir, file_path, label_name])

    
# Create DataFrame
df = pd.DataFrame(data, columns=["directory", "image_path", "label"])
df
# Out:
#      directory                                         image_path      label
# 0        train   ./data/chest_xray\train\NORMAL\IM-0115-0001.jpeg     NORMAL
# 1        train   ./data/chest_xray\train\NORMAL\IM-0117-0001.jpeg     NORMAL
# 2        train   ./data/chest_xray\train\NORMAL\IM-0119-0001.jpeg     NORMAL
# 3        train   ./data/chest_xray\train\NORMAL\IM-0122-0001.jpeg     NORMAL
# 4        train   ./data/chest_xray\train\NORMAL\IM-0125-0001.jpeg     NORMAL
# ...        ...                                                ...        ...
# 5851       val  ./data/chest_xray\val\PNEUMONIA\person1949_bac...  PNEUMONIA
# 5852       val  ./data/chest_xray\val\PNEUMONIA\person1950_bac...  PNEUMONIA
# 5853       val  ./data/chest_xray\val\PNEUMONIA\person1951_bac...  PNEUMONIA
# 5854       val  ./data/chest_xray\val\PNEUMONIA\person1952_bac...  PNEUMONIA
# 5855       val  ./data/chest_xray\val\PNEUMONIA\person1954_bac...  PNEUMONIA
#
# [5856 rows x 3 columns]

# %%
def resize_image(img_path, output_dir, target_size, img_name):
    '''Function to resize the supplied image.  
        img_path = path to the image for resizing
        output_dir = file path for saving the resized image
        target_size = target size of the image (i.e. (256,256))
        image_name = Name for the resized image'''
    img = Image.open(img_path)
    img_resized = img.resize(target_size, Image.LANCZOS)
    output_path = output_dir / img_name
    img_resized.save(output_path)

# %%
# Variables for use in the resize image function
sample_size = 1000
normal_output_dir = Path("./data/chest_xray/resized/normal")
pneumonia_output_dir = Path("./data/chest_xray/resized/pneumonia")
target_size = (128, 128)

# Split out samples for Normal and Pneumonia
normal_sample = df[df['label'] == 'NORMAL']['image_path'].sample(n=sample_size)
pneumonia_sample = df[df['label'] == 'PNEUMONIA']['image_path'].sample(n=sample_size)

# Create output directory if it doesn't exist
normal_output_dir.mkdir(parents=True, exist_ok=True)
pneumonia_output_dir.mkdir(parents=True, exist_ok=True)

# Loop through normal sample DF and process images.
i=0
for img_path in normal_sample:
    resize_image(Path(img_path), normal_output_dir, target_size, f'img_{i}.jpeg')
    i = i + 1

# Loop through normal sample DF and process images.
i=0
for img_path in pneumonia_sample:
    resize_image(Path(img_path), pneumonia_output_dir, target_size, f'img_{i}.jpeg')
    i = i + 1

# %% [markdown]
# # Setup Environment
# This section of the Notebook sets up the StyleGAN model, fine-tunes it for use with X-Ray images, snapshots the model, and then uses the model for generating new images.   This portion of the notebook must be run with a GPU, and is recommended to run in Google Collab.

# %%
# Load Libraries used in this notebook
import torch
import os

# %%
# Verify GPU is avialable
print(torch.cuda.is_available())
print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# True
# Number of GPUs: 1

# %%
# Install additional environment libraries used by StyleGan
# !pip install timm==0.4.12 ftfy==6.1.1 ninja==1.10.2 opensimplex
# Out:
# Requirement already satisfied: timm==0.4.12 in /usr/local/lib/python3.11/dist-packages (0.4.12)
# Requirement already satisfied: ftfy==6.1.1 in /usr/local/lib/python3.11/dist-packages (6.1.1)
# Requirement already satisfied: ninja==1.10.2 in /usr/local/lib/python3.11/dist-packages (1.10.2)
# Requirement already satisfied: opensimplex in /usr/local/lib/python3.11/dist-packages (0.4.5.1)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.11/dist-packages (from timm==0.4.12) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm==0.4.12) (0.21.0+cu124)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from ftfy==6.1.1) (0.2.13)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from opensimplex) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.4.12) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.4->timm==0.4.12) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm==0.4.12) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (3.0.2)

# %%
# Clone the Style3GAN repository and verify it exists
repo_url = "https://github.com/NVlabs/stylegan3.git"
repo_dir = "../content/stylegan3"

# Remove the directory if it already exists to avoid conflicts
if os.path.exists(repo_dir):
    # !rm -rf {repo_dir}

# Clone the repo
# !git clone {repo_url} {repo_dir}

# Change directory to the repo
# %cd {repo_dir}

# Verify the contents
# !ls
# Out:
# Cloning into '../content/stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 212 (delta 99), reused 90 (delta 90), pack-reused 49 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 17.90 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/stylegan3
# avg_spectra.py	 dnnlib      environment.yml  gui_utils    metrics	training       viz
# calc_metrics.py  Dockerfile  gen_images.py    legacy.py    README.md	train.py
# dataset_tool.py  docs	     gen_video.py     LICENSE.txt  torch_utils	visualizer.py

# %%
# Prepare Image data using StyleGan dataset tool
#   NOTE:  IMAGES YOU ARE USING TO FINE TUNE THE GAN MUST BE IN THE SOURCE
CMD = "python /content/stylegan3/dataset_tool.py "\
  "--source /content/data/normal "\
  "--dest /content/data/dataset/normal"

# !{CMD}
# Out:
#  78% 731/938 [00:00<00:00, 1047.08it/s]Error: Image 00000/img00000760.png attributes must be equal across all images of the dataset.  Got:
#   dataset width/cur image width: 128/128
#   dataset height/cur image height: 128/128
#   dataset channels/cur image channels: 1/3
#  81% 760/938 [00:00<00:00, 1038.35it/s]

# %%
# Command for clearing out newly created dataset if things go wrong
#!rm -R /content/data/dataset/pneumonia*

# %% [markdown]
# # Fine-Tune Model
#
# This section will begin the fine-tuning of the StyleGan.  This process can be quite lengthy depending on the environment and avialable infrastructure.
# This notebook was run on a Google Collab "A100 GPU" runtime.  It was manually stopped once generated images looked indiscernible from real images.

# %%
# Data paths to the Experiement and Dataset directories
EXPERIMENTS = "/content/data/experiments/pneumonia"
DATA = "/content/data/dataset/pneumonia"
SNAP = 10

# Build the command and run it
cmd = f"/usr/bin/python3 /content/stylegan3/train.py "\
  f"--snap {SNAP} --outdir {EXPERIMENTS} --data {DATA} --cfg stylegan2 --gpus 1 --batch 32 --gamma 6.6 "
# !{cmd}
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan2.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "fused_modconv_default": "inference_only"
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 6.6,
#     "style_mixing_prob": 0.9,
#     "pl_weight": 2,
#     "pl_no_weight_grad": true
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 3
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/data/dataset/pneumonia",
#     "use_labels": false,
#     "max_size": 760,
#     "xflip": false,
#     "resolution": 128,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 32,
#   "batch_gpu": 32,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "total_kimg": 25000,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "random_seed": 0,
#   "ema_kimg": 10.0,
#   "G_reg_interval": 4,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "run_dir": "/content/data/experiments/pneumonia/00000-stylegan2-pneumonia-gpus1-batch32-gamma6.6"
# }
#
# Output directory:    /content/data/experiments/pneumonia/00000-stylegan2-pneumonia-gpus1-batch32-gamma6.6
# Number of GPUs:      1
# Batch size:          32 images
# Training duration:   25000 kimg
# Dataset path:        /content/data/dataset/pneumonia
# Dataset size:        760 images
# Dataset resolution:  128
# Dataset labels:      False
# Dataset x-flips:     False
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/sampler.py:77: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn(
#
# Num images:  760
# Image shape: [1, 128, 128]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
#
# Generator             Parameters  Buffers  Output shape         Datatype
# ---                   ---         ---      ---                  ---
# mapping.fc0           262656      -        [32, 512]            float32
# mapping.fc1           262656      -        [32, 512]            float32
# mapping.fc2           262656      -        [32, 512]            float32
# mapping.fc3           262656      -        [32, 512]            float32
# mapping.fc4           262656      -        [32, 512]            float32
# mapping.fc5           262656      -        [32, 512]            float32
# mapping.fc6           262656      -        [32, 512]            float32
# mapping.fc7           262656      -        [32, 512]            float32
# mapping               -           512      [32, 12, 512]        float32
# synthesis.b4.conv1    2622465     32       [32, 512, 4, 4]      float32
# synthesis.b4.torgb    263169      -        [32, 1, 4, 4]        float32
# synthesis.b4:0        8192        16       [32, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [32, 1, 4, 4]        float32
# synthesis.b8.conv0    2622465     80       [32, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [32, 512, 8, 8]      float32
# synthesis.b8.torgb    263169      -        [32, 1, 8, 8]        float32
# synthesis.b8:0        -           16       [32, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [32, 1, 8, 8]        float32
# synthesis.b16.conv0   2622465     272      [32, 512, 16, 16]    float16
# synthesis.b16.conv1   2622465     272      [32, 512, 16, 16]    float16
# synthesis.b16.torgb   263169      -        [32, 1, 16, 16]      float16
# synthesis.b16:0       -           16       [32, 512, 16, 16]    float16
# synthesis.b16:1       -           -        [32, 1, 16, 16]      float32
# synthesis.b32.conv0   2622465     1040     [32, 512, 32, 32]    float16
# synthesis.b32.conv1   2622465     1040     [32, 512, 32, 32]    float16
# synthesis.b32.torgb   263169      -        [32, 1, 32, 32]      float16
# synthesis.b32:0       -           16       [32, 512, 32, 32]    float16
# synthesis.b32:1       -           -        [32, 1, 32, 32]      float32
# synthesis.b64.conv0   2622465     4112     [32, 512, 64, 64]    float16
# synthesis.b64.conv1   2622465     4112     [32, 512, 64, 64]    float16
# synthesis.b64.torgb   263169      -        [32, 1, 64, 64]      float16
# synthesis.b64:0       -           16       [32, 512, 64, 64]    float16
# synthesis.b64:1       -           -        [32, 1, 64, 64]      float32
# synthesis.b128.conv0  1442561     16400    [32, 256, 128, 128]  float16
# synthesis.b128.conv1  721409      16400    [32, 256, 128, 128]  float16
# synthesis.b128.torgb  131585      -        [32, 1, 128, 128]    float16
# synthesis.b128:0      -           16       [32, 256, 128, 128]  float16
# synthesis.b128:1      -           -        [32, 1, 128, 128]    float32
# ---                   ---         ---      ---                  ---
# Total                 29323025    44448    -                    -
#
#
# Discriminator  Parameters  Buffers  Output shape         Datatype
# ---            ---         ---      ---                  ---
# b128.fromrgb   512         16       [32, 256, 128, 128]  float16
# b128.skip      131072      16       [32, 512, 64, 64]    float16
# b128.conv0     590080      16       [32, 256, 128, 128]  float16
# b128.conv1     1180160     16       [32, 512, 64, 64]    float16
# b128           -           16       [32, 512, 64, 64]    float16
# b64.skip       262144      16       [32, 512, 32, 32]    float16
# b64.conv0      2359808     16       [32, 512, 64, 64]    float16
# b64.conv1      2359808     16       [32, 512, 32, 32]    float16
# b64            -           16       [32, 512, 32, 32]    float16
# b32.skip       262144      16       [32, 512, 16, 16]    float16
# b32.conv0      2359808     16       [32, 512, 32, 32]    float16
# b32.conv1      2359808     16       [32, 512, 16, 16]    float16
# b32            -           16       [32, 512, 16, 16]    float16
# b16.skip       262144      16       [32, 512, 8, 8]      float16
# b16.conv0      2359808     16       [32, 512, 16, 16]    float16
# b16.conv1      2359808     16       [32, 512, 8, 8]      float16
# b16            -           16       [32, 512, 8, 8]      float16
# b8.skip        262144      16       [32, 512, 4, 4]      float32
# b8.conv0       2359808     16       [32, 512, 8, 8]      float32
# b8.conv1       2359808     16       [32, 512, 4, 4]      float32
# b8             -           16       [32, 512, 4, 4]      float32
# b4.mbstd       -           -        [32, 513, 4, 4]      float32
# b4.conv        2364416     16       [32, 512, 4, 4]      float32
# b4.fc          4194816     -        [32, 512]            float32
# b4.out         513         -        [32, 1]              float32
# ---            ---         ---      ---                  ---
# Total          28388609    352      -                    -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2025-03-19 01:38:21.992661: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-19 01:38:22.009503: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742348302.028000   36112 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742348302.033465   36112 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-19 01:38:22.052333: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 1m 33s       sec/tick 10.0    sec/kimg 312.35  maintenance 82.9   cpumem 2.76   gpumem 37.78  reserved 38.43  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 389.5010575608252}, "metric": "fid50k_full", "total_time": 315.7313072681427, "total_time_str": "5m 16s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1742348634.4920022}
# tick 1     kimg 4.0      time 7m 37s       sec/tick 44.4    sec/kimg 11.10   maintenance 319.4  cpumem 3.29   gpumem 34.37  reserved 34.59  augment 0.003
# tick 2     kimg 8.0      time 8m 21s       sec/tick 44.6    sec/kimg 11.14   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.001
# tick 3     kimg 12.0     time 9m 06s       sec/tick 44.7    sec/kimg 11.16   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 4     kimg 16.0     time 9m 51s       sec/tick 44.8    sec/kimg 11.21   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 5     kimg 20.0     time 10m 36s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 6     kimg 24.0     time 11m 20s      sec/tick 44.5    sec/kimg 11.13   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 7     kimg 28.0     time 12m 05s      sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 8     kimg 32.0     time 12m 50s      sec/tick 44.8    sec/kimg 11.20   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 9     kimg 36.0     time 13m 34s      sec/tick 44.7    sec/kimg 11.16   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# tick 10    kimg 40.0     time 14m 19s      sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.29   gpumem 8.45   reserved 10.23  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 241.15790291644652}, "metric": "fid50k_full", "total_time": 304.21492743492126, "total_time_str": "5m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1742349389.9242003}
# tick 11    kimg 44.0     time 20m 12s      sec/tick 44.5    sec/kimg 11.12   maintenance 308.7  cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 12    kimg 48.0     time 20m 57s      sec/tick 44.8    sec/kimg 11.19   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 13    kimg 52.0     time 21m 42s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 14    kimg 56.0     time 22m 26s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 15    kimg 60.0     time 23m 11s      sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 16    kimg 64.0     time 23m 56s      sec/tick 44.8    sec/kimg 11.19   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 17    kimg 68.0     time 24m 41s      sec/tick 44.5    sec/kimg 11.13   maintenance 0.1    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 18    kimg 72.0     time 25m 25s      sec/tick 44.7    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 19    kimg 76.0     time 26m 10s      sec/tick 44.7    sec/kimg 11.18   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 20    kimg 80.0     time 26m 55s      sec/tick 44.8    sec/kimg 11.20   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 127.39622474868804}, "metric": "fid50k_full", "total_time": 304.0035786628723, "total_time_str": "5m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1742350145.863776}
# tick 21    kimg 84.0     time 32m 48s      sec/tick 44.6    sec/kimg 11.14   maintenance 308.9  cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 22    kimg 88.0     time 33m 33s      sec/tick 44.5    sec/kimg 11.12   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 23    kimg 92.0     time 34m 18s      sec/tick 44.7    sec/kimg 11.18   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 24    kimg 96.0     time 35m 02s      sec/tick 44.8    sec/kimg 11.20   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 25    kimg 100.0    time 35m 47s      sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 26    kimg 104.0    time 36m 32s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 27    kimg 108.0    time 37m 16s      sec/tick 44.5    sec/kimg 11.13   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 28    kimg 112.0    time 38m 01s      sec/tick 44.8    sec/kimg 11.21   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 29    kimg 116.0    time 38m 46s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 30    kimg 120.0    time 39m 31s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 114.71069579747288}, "metric": "fid50k_full", "total_time": 303.019588470459, "total_time_str": "5m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1742350900.7173653}
# tick 31    kimg 124.0    time 45m 23s      sec/tick 44.6    sec/kimg 11.14   maintenance 308.0  cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 32    kimg 128.0    time 46m 08s      sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 33    kimg 132.0    time 46m 52s      sec/tick 44.5    sec/kimg 11.12   maintenance 0.1    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 34    kimg 136.0    time 47m 37s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 35    kimg 140.0    time 48m 22s      sec/tick 44.7    sec/kimg 11.18   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 36    kimg 144.0    time 49m 07s      sec/tick 44.9    sec/kimg 11.21   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 37    kimg 148.0    time 49m 51s      sec/tick 44.7    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 38    kimg 152.0    time 50m 36s      sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 39    kimg 156.0    time 51m 21s      sec/tick 44.8    sec/kimg 11.21   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 40    kimg 160.0    time 52m 06s      sec/tick 45.0    sec/kimg 11.24   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 105.7465850462537}, "metric": "fid50k_full", "total_time": 303.89652943611145, "total_time_str": "5m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1742351656.9116857}
# tick 41    kimg 164.0    time 57m 59s      sec/tick 44.6    sec/kimg 11.15   maintenance 308.8  cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 42    kimg 168.0    time 58m 44s      sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 43    kimg 172.0    time 59m 29s      sec/tick 44.6    sec/kimg 11.14   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 44    kimg 176.0    time 1h 00m 13s   sec/tick 44.8    sec/kimg 11.20   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 45    kimg 180.0    time 1h 00m 58s   sec/tick 44.7    sec/kimg 11.18   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 46    kimg 184.0    time 1h 01m 43s   sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 47    kimg 188.0    time 1h 02m 28s   sec/tick 44.8    sec/kimg 11.19   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 48    kimg 192.0    time 1h 03m 13s   sec/tick 44.8    sec/kimg 11.19   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 49    kimg 196.0    time 1h 03m 57s   sec/tick 44.5    sec/kimg 11.13   maintenance 0.1    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 50    kimg 200.0    time 1h 04m 42s   sec/tick 44.6    sec/kimg 11.16   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 86.25929018499659}, "metric": "fid50k_full", "total_time": 305.7035732269287, "total_time_str": "5m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1742352414.6118572}
# tick 51    kimg 204.0    time 1h 10m 37s   sec/tick 44.6    sec/kimg 11.16   maintenance 310.6  cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 52    kimg 208.0    time 1h 11m 22s   sec/tick 44.8    sec/kimg 11.19   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 53    kimg 212.0    time 1h 12m 07s   sec/tick 44.7    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 54    kimg 216.0    time 1h 12m 51s   sec/tick 44.6    sec/kimg 11.14   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 55    kimg 220.0    time 1h 13m 36s   sec/tick 44.8    sec/kimg 11.19   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 56    kimg 224.0    time 1h 14m 21s   sec/tick 44.8    sec/kimg 11.21   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 57    kimg 228.0    time 1h 15m 05s   sec/tick 44.7    sec/kimg 11.17   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 58    kimg 232.0    time 1h 15m 50s   sec/tick 44.7    sec/kimg 11.16   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 59    kimg 236.0    time 1h 16m 35s   sec/tick 44.6    sec/kimg 11.14   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# tick 60    kimg 240.0    time 1h 17m 20s   sec/tick 44.8    sec/kimg 11.21   maintenance 0.0    cpumem 3.24   gpumem 8.45   reserved 10.23  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 79.3989034159338}, "metric": "fid50k_full", "total_time": 309.73468685150146, "total_time_str": "5m 10s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000240.pkl", "timestamp": 1742353176.7201903}
# tick 61    kimg 244.0    time 1h 23m 20s   sec/tick 45.0    sec/kimg 11.25   maintenance 314.9  cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
# tick 62    kimg 248.0    time 1h 24m 05s   sec/tick 45.0    sec/kimg 11.26   maintenance 0.0    cpumem 3.25   gpumem 8.45   reserved 10.23  augment 0.000
#
# Aborted!
# ^C

# %% [markdown]
# # Load and use Model
#
# Models are snapshot every 10,000 generated images (10 ticks).  The following section loads the model from a .pkl file and generates x-ray images for use in other machine learning applications.

# %%
# Import additional libraries used for generating images with the StyleGAN 
import pickle
import numpy as np
import dnnlib
import torch_utils
from tqdm import tqdm
from PIL import Image

# %% [markdown]
# The images being generated are grayscale, which seems to be problematic for StyleGAN3.  To get around this, the following edit needs to be made to the gen_images.py file from the downlaoded StyelGan repo code.
#
# **COMMENT OUT THESE TWO LINES**
#   #img = (img.permute(0, 2, 3, 1) * 127.5 + 128).clamp(0, 255).to(torch.uint8)
#   #PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(f'{outdir}/seed{seed:04d}.png')
#
#
# **PUT IN THESE TWO LINES**
# img = (img.permute(0, 1, 2, 3) * 127.5 + 128).clamp(0, 255).to(torch.uint8)
# PIL.Image.fromarray(img[0].cpu().numpy()[0]).save(f'{outdir}/seed{seed:04d}.png')

# %%
# Path to the model
model_path = "/content/models/stylegan-penumonia-000240.pkl"

img_output_path = "/content/drive/MyDrive/GAN-Images/Pneumonia"

# Generate images
cmd = f"/usr/bin/python3 /content/stylegan3/gen_images.py "\
  f"--outdir={img_output_path} --trunc=1 --seeds=1-1000 --network={model_path} "
# !{cmd}
# Out:
# Loading networks from "/content/models/stylegan-penumonia-000240.pkl"...
# Generating image for seed 1 (0/1000) ...
# Setting up PyTorch plugin "bias_act_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Generating image for seed 2 (1/1000) ...
# Generating image for seed 3 (2/1000) ...
# Generating image for seed 4 (3/1000) ...
# Generating image for seed 5 (4/1000) ...
# Generating image for seed 6 (5/1000) ...
# Generating image for seed 7 (6/1000) ...
# Generating image for seed 8 (7/1000) ...
# Generating image for seed 9 (8/1000) ...
# Generating image for seed 10 (9/1000) ...
# Generating image for seed 11 (10/1000) ...
# Generating image for seed 12 (11/1000) ...
# Generating image for seed 13 (12/1000) ...
# Generating image for seed 14 (13/1000) ...
# Generating image for seed 15 (14/1000) ...
# Generating image for seed 16 (15/1000) ...
# Generating image for seed 17 (16/1000) ...
# Generating image for seed 18 (17/1000) ...
# Generating image for seed 19 (18/1000) ...
# Generating image for seed 20 (19/1000) ...
# Generating image for seed 21 (20/1000) ...
# Generating image for seed 22 (21/1000) ...
# Generating image for seed 23 (22/1000) ...
# Generating image for seed 24 (23/1000) ...
# Generating image for seed 25 (24/1000) ...
# Generating image for seed 26 (25/1000) ...
# Generating image for seed 27 (26/1000) ...
# Generating image for seed 28 (27/1000) ...
# Generating image for seed 29 (28/1000) ...
# Generating image for seed 30 (29/1000) ...
# Generating image for seed 31 (30/1000) ...
# Generating image for seed 32 (31/1000) ...
# Generating image for seed 33 (32/1000) ...
# Generating image for seed 34 (33/1000) ...
# Generating image for seed 35 (34/1000) ...
# Generating image for seed 36 (35/1000) ...
# Generating image for seed 37 (36/1000) ...
# Generating image for seed 38 (37/1000) ...
# Generating image for seed 39 (38/1000) ...
# Generating image for seed 40 (39/1000) ...
# Generating image for seed 41 (40/1000) ...
# Generating image for seed 42 (41/1000) ...
# Generating image for seed 43 (42/1000) ...
# Generating image for seed 44 (43/1000) ...
# Generating image for seed 45 (44/1000) ...
# Generating image for seed 46 (45/1000) ...
# Generating image for seed 47 (46/1000) ...
# Generating image for seed 48 (47/1000) ...
# Generating image for seed 49 (48/1000) ...
# Generating image for seed 50 (49/1000) ...
# Generating image for seed 51 (50/1000) ...
# Generating image for seed 52 (51/1000) ...
# Generating image for seed 53 (52/1000) ...
# Generating image for seed 54 (53/1000) ...
# Generating image for seed 55 (54/1000) ...
# Generating image for seed 56 (55/1000) ...
# Generating image for seed 57 (56/1000) ...
# Generating image for seed 58 (57/1000) ...
# Generating image for seed 59 (58/1000) ...
# Generating image for seed 60 (59/1000) ...
# Generating image for seed 61 (60/1000) ...
# Generating image for seed 62 (61/1000) ...
# Generating image for seed 63 (62/1000) ...
# Generating image for seed 64 (63/1000) ...
# Generating image for seed 65 (64/1000) ...
# Generating image for seed 66 (65/1000) ...
# Generating image for seed 67 (66/1000) ...
# Generating image for seed 68 (67/1000) ...
# Generating image for seed 69 (68/1000) ...
# Generating image for seed 70 (69/1000) ...
# Generating image for seed 71 (70/1000) ...
# Generating image for seed 72 (71/1000) ...
# Generating image for seed 73 (72/1000) ...
# Generating image for seed 74 (73/1000) ...
# Generating image for seed 75 (74/1000) ...
# Generating image for seed 76 (75/1000) ...
# Generating image for seed 77 (76/1000) ...
# Generating image for seed 78 (77/1000) ...
# Generating image for seed 79 (78/1000) ...
# Generating image for seed 80 (79/1000) ...
# Generating image for seed 81 (80/1000) ...
# Generating image for seed 82 (81/1000) ...
# Generating image for seed 83 (82/1000) ...
# Generating image for seed 84 (83/1000) ...
# Generating image for seed 85 (84/1000) ...
# Generating image for seed 86 (85/1000) ...
# Generating image for seed 87 (86/1000) ...
# Generating image for seed 88 (87/1000) ...
# Generating image for seed 89 (88/1000) ...
# Generating image for seed 90 (89/1000) ...
# Generating image for seed 91 (90/1000) ...
# Generating image for seed 92 (91/1000) ...
# Generating image for seed 93 (92/1000) ...
# Generating image for seed 94 (93/1000) ...
# Generating image for seed 95 (94/1000) ...
# Generating image for seed 96 (95/1000) ...
# Generating image for seed 97 (96/1000) ...
# Generating image for seed 98 (97/1000) ...
# Generating image for seed 99 (98/1000) ...
# Generating image for seed 100 (99/1000) ...
# Generating image for seed 101 (100/1000) ...
# Generating image for seed 102 (101/1000) ...
# Generating image for seed 103 (102/1000) ...
# Generating image for seed 104 (103/1000) ...
# Generating image for seed 105 (104/1000) ...
# Generating image for seed 106 (105/1000) ...
# Generating image for seed 107 (106/1000) ...
# Generating image for seed 108 (107/1000) ...
# Generating image for seed 109 (108/1000) ...
# Generating image for seed 110 (109/1000) ...
# Generating image for seed 111 (110/1000) ...
# Generating image for seed 112 (111/1000) ...
# Generating image for seed 113 (112/1000) ...
# Generating image for seed 114 (113/1000) ...
# Generating image for seed 115 (114/1000) ...
# Generating image for seed 116 (115/1000) ...
# Generating image for seed 117 (116/1000) ...
# Generating image for seed 118 (117/1000) ...
# Generating image for seed 119 (118/1000) ...
# Generating image for seed 120 (119/1000) ...
# Generating image for seed 121 (120/1000) ...
# Generating image for seed 122 (121/1000) ...
# Generating image for seed 123 (122/1000) ...
# Generating image for seed 124 (123/1000) ...
# Generating image for seed 125 (124/1000) ...
# Generating image for seed 126 (125/1000) ...
# Generating image for seed 127 (126/1000) ...
# Generating image for seed 128 (127/1000) ...
# Generating image for seed 129 (128/1000) ...
# Generating image for seed 130 (129/1000) ...
# Generating image for seed 131 (130/1000) ...
# Generating image for seed 132 (131/1000) ...
# Generating image for seed 133 (132/1000) ...
# Generating image for seed 134 (133/1000) ...
# Generating image for seed 135 (134/1000) ...
# Generating image for seed 136 (135/1000) ...
# Generating image for seed 137 (136/1000) ...
# Generating image for seed 138 (137/1000) ...
# Generating image for seed 139 (138/1000) ...
# Generating image for seed 140 (139/1000) ...
# Generating image for seed 141 (140/1000) ...
# Generating image for seed 142 (141/1000) ...
# Generating image for seed 143 (142/1000) ...
# Generating image for seed 144 (143/1000) ...
# Generating image for seed 145 (144/1000) ...
# Generating image for seed 146 (145/1000) ...
# Generating image for seed 147 (146/1000) ...
# Generating image for seed 148 (147/1000) ...
# Generating image for seed 149 (148/1000) ...
# Generating image for seed 150 (149/1000) ...
# Generating image for seed 151 (150/1000) ...
# Generating image for seed 152 (151/1000) ...
# Generating image for seed 153 (152/1000) ...
# Generating image for seed 154 (153/1000) ...
# Generating image for seed 155 (154/1000) ...
# Generating image for seed 156 (155/1000) ...
# Generating image for seed 157 (156/1000) ...
# Generating image for seed 158 (157/1000) ...
# Generating image for seed 159 (158/1000) ...
# Generating image for seed 160 (159/1000) ...
# Generating image for seed 161 (160/1000) ...
# Generating image for seed 162 (161/1000) ...
# Generating image for seed 163 (162/1000) ...
# Generating image for seed 164 (163/1000) ...
# Generating image for seed 165 (164/1000) ...
# Generating image for seed 166 (165/1000) ...
# Generating image for seed 167 (166/1000) ...
# Generating image for seed 168 (167/1000) ...
# Generating image for seed 169 (168/1000) ...
# Generating image for seed 170 (169/1000) ...
# Generating image for seed 171 (170/1000) ...
# Generating image for seed 172 (171/1000) ...
# Generating image for seed 173 (172/1000) ...
# Generating image for seed 174 (173/1000) ...
# Generating image for seed 175 (174/1000) ...
# Generating image for seed 176 (175/1000) ...
# Generating image for seed 177 (176/1000) ...
# Generating image for seed 178 (177/1000) ...
# Generating image for seed 179 (178/1000) ...
# Generating image for seed 180 (179/1000) ...
# Generating image for seed 181 (180/1000) ...
# Generating image for seed 182 (181/1000) ...
# Generating image for seed 183 (182/1000) ...
# Generating image for seed 184 (183/1000) ...
# Generating image for seed 185 (184/1000) ...
# Generating image for seed 186 (185/1000) ...
# Generating image for seed 187 (186/1000) ...
# Generating image for seed 188 (187/1000) ...
# Generating image for seed 189 (188/1000) ...
# Generating image for seed 190 (189/1000) ...
# Generating image for seed 191 (190/1000) ...
# Generating image for seed 192 (191/1000) ...
# Generating image for seed 193 (192/1000) ...
# Generating image for seed 194 (193/1000) ...
# Generating image for seed 195 (194/1000) ...
# Generating image for seed 196 (195/1000) ...
# Generating image for seed 197 (196/1000) ...
# Generating image for seed 198 (197/1000) ...
# Generating image for seed 199 (198/1000) ...
# Generating image for seed 200 (199/1000) ...
# Generating image for seed 201 (200/1000) ...
# Generating image for seed 202 (201/1000) ...
# Generating image for seed 203 (202/1000) ...
# Generating image for seed 204 (203/1000) ...
# Generating image for seed 205 (204/1000) ...
# Generating image for seed 206 (205/1000) ...
# Generating image for seed 207 (206/1000) ...
# Generating image for seed 208 (207/1000) ...
# Generating image for seed 209 (208/1000) ...
# Generating image for seed 210 (209/1000) ...
# Generating image for seed 211 (210/1000) ...
# Generating image for seed 212 (211/1000) ...
# Generating image for seed 213 (212/1000) ...
# Generating image for seed 214 (213/1000) ...
# Generating image for seed 215 (214/1000) ...
# Generating image for seed 216 (215/1000) ...
# Generating image for seed 217 (216/1000) ...
# Generating image for seed 218 (217/1000) ...
# Generating image for seed 219 (218/1000) ...
# Generating image for seed 220 (219/1000) ...
# Generating image for seed 221 (220/1000) ...
# Generating image for seed 222 (221/1000) ...
# Generating image for seed 223 (222/1000) ...
# Generating image for seed 224 (223/1000) ...
# Generating image for seed 225 (224/1000) ...
# Generating image for seed 226 (225/1000) ...
# Generating image for seed 227 (226/1000) ...
# Generating image for seed 228 (227/1000) ...
# Generating image for seed 229 (228/1000) ...
# Generating image for seed 230 (229/1000) ...
# Generating image for seed 231 (230/1000) ...
# Generating image for seed 232 (231/1000) ...
# Generating image for seed 233 (232/1000) ...
# Generating image for seed 234 (233/1000) ...
# Generating image for seed 235 (234/1000) ...
# Generating image for seed 236 (235/1000) ...
# Generating image for seed 237 (236/1000) ...
# Generating image for seed 238 (237/1000) ...
# Generating image for seed 239 (238/1000) ...
# Generating image for seed 240 (239/1000) ...
# Generating image for seed 241 (240/1000) ...
# Generating image for seed 242 (241/1000) ...
# Generating image for seed 243 (242/1000) ...
# Generating image for seed 244 (243/1000) ...
# Generating image for seed 245 (244/1000) ...
# Generating image for seed 246 (245/1000) ...
# Generating image for seed 247 (246/1000) ...
# Generating image for seed 248 (247/1000) ...
# Generating image for seed 249 (248/1000) ...
# Generating image for seed 250 (249/1000) ...
# Generating image for seed 251 (250/1000) ...
# Generating image for seed 252 (251/1000) ...
# Generating image for seed 253 (252/1000) ...
# Generating image for seed 254 (253/1000) ...
# Generating image for seed 255 (254/1000) ...
# Generating image for seed 256 (255/1000) ...
# Generating image for seed 257 (256/1000) ...
# Generating image for seed 258 (257/1000) ...
# Generating image for seed 259 (258/1000) ...
# Generating image for seed 260 (259/1000) ...
# Generating image for seed 261 (260/1000) ...
# Generating image for seed 262 (261/1000) ...
# Generating image for seed 263 (262/1000) ...
# Generating image for seed 264 (263/1000) ...
# Generating image for seed 265 (264/1000) ...
# Generating image for seed 266 (265/1000) ...
# Generating image for seed 267 (266/1000) ...
# Generating image for seed 268 (267/1000) ...
# Generating image for seed 269 (268/1000) ...
# Generating image for seed 270 (269/1000) ...
# Generating image for seed 271 (270/1000) ...
# Generating image for seed 272 (271/1000) ...
# Generating image for seed 273 (272/1000) ...
# Generating image for seed 274 (273/1000) ...
# Generating image for seed 275 (274/1000) ...
# Generating image for seed 276 (275/1000) ...
# Generating image for seed 277 (276/1000) ...
# Generating image for seed 278 (277/1000) ...
# Generating image for seed 279 (278/1000) ...
# Generating image for seed 280 (279/1000) ...
# Generating image for seed 281 (280/1000) ...
# Generating image for seed 282 (281/1000) ...
# Generating image for seed 283 (282/1000) ...
# Generating image for seed 284 (283/1000) ...
# Generating image for seed 285 (284/1000) ...
# Generating image for seed 286 (285/1000) ...
# Generating image for seed 287 (286/1000) ...
# Generating image for seed 288 (287/1000) ...
# Generating image for seed 289 (288/1000) ...
# Generating image for seed 290 (289/1000) ...
# Generating image for seed 291 (290/1000) ...
# Generating image for seed 292 (291/1000) ...
# Generating image for seed 293 (292/1000) ...
# Generating image for seed 294 (293/1000) ...
# Generating image for seed 295 (294/1000) ...
# Generating image for seed 296 (295/1000) ...
# Generating image for seed 297 (296/1000) ...
# Generating image for seed 298 (297/1000) ...
# Generating image for seed 299 (298/1000) ...
# Generating image for seed 300 (299/1000) ...
# Generating image for seed 301 (300/1000) ...
# Generating image for seed 302 (301/1000) ...
# Generating image for seed 303 (302/1000) ...
# Generating image for seed 304 (303/1000) ...
# Generating image for seed 305 (304/1000) ...
# Generating image for seed 306 (305/1000) ...
# Generating image for seed 307 (306/1000) ...
# Generating image for seed 308 (307/1000) ...
# Generating image for seed 309 (308/1000) ...
# Generating image for seed 310 (309/1000) ...
# Generating image for seed 311 (310/1000) ...
# Generating image for seed 312 (311/1000) ...
# Generating image for seed 313 (312/1000) ...
# Generating image for seed 314 (313/1000) ...
# Generating image for seed 315 (314/1000) ...
# Generating image for seed 316 (315/1000) ...
# Generating image for seed 317 (316/1000) ...
# Generating image for seed 318 (317/1000) ...
# Generating image for seed 319 (318/1000) ...
# Generating image for seed 320 (319/1000) ...
# Generating image for seed 321 (320/1000) ...
# Generating image for seed 322 (321/1000) ...
# Generating image for seed 323 (322/1000) ...
# Generating image for seed 324 (323/1000) ...
# Generating image for seed 325 (324/1000) ...
# Generating image for seed 326 (325/1000) ...
# Generating image for seed 327 (326/1000) ...
# Generating image for seed 328 (327/1000) ...
# Generating image for seed 329 (328/1000) ...
# Generating image for seed 330 (329/1000) ...
# Generating image for seed 331 (330/1000) ...
# Generating image for seed 332 (331/1000) ...
# Generating image for seed 333 (332/1000) ...
# Generating image for seed 334 (333/1000) ...
# Generating image for seed 335 (334/1000) ...
# Generating image for seed 336 (335/1000) ...
# Generating image for seed 337 (336/1000) ...
# Generating image for seed 338 (337/1000) ...
# Generating image for seed 339 (338/1000) ...
# Generating image for seed 340 (339/1000) ...
# Generating image for seed 341 (340/1000) ...
# Generating image for seed 342 (341/1000) ...
# Generating image for seed 343 (342/1000) ...
# Generating image for seed 344 (343/1000) ...
# Generating image for seed 345 (344/1000) ...
# Generating image for seed 346 (345/1000) ...
# Generating image for seed 347 (346/1000) ...
# Generating image for seed 348 (347/1000) ...
# Generating image for seed 349 (348/1000) ...
# Generating image for seed 350 (349/1000) ...
# Generating image for seed 351 (350/1000) ...
# Generating image for seed 352 (351/1000) ...
# Generating image for seed 353 (352/1000) ...
# Generating image for seed 354 (353/1000) ...
# Generating image for seed 355 (354/1000) ...
# Generating image for seed 356 (355/1000) ...
# Generating image for seed 357 (356/1000) ...
# Generating image for seed 358 (357/1000) ...
# Generating image for seed 359 (358/1000) ...
# Generating image for seed 360 (359/1000) ...
# Generating image for seed 361 (360/1000) ...
# Generating image for seed 362 (361/1000) ...
# Generating image for seed 363 (362/1000) ...
# Generating image for seed 364 (363/1000) ...
# Generating image for seed 365 (364/1000) ...
# Generating image for seed 366 (365/1000) ...
# Generating image for seed 367 (366/1000) ...
# Generating image for seed 368 (367/1000) ...
# Generating image for seed 369 (368/1000) ...
# Generating image for seed 370 (369/1000) ...
# Generating image for seed 371 (370/1000) ...
# Generating image for seed 372 (371/1000) ...
# Generating image for seed 373 (372/1000) ...
# Generating image for seed 374 (373/1000) ...
# Generating image for seed 375 (374/1000) ...
# Generating image for seed 376 (375/1000) ...
# Generating image for seed 377 (376/1000) ...
# Generating image for seed 378 (377/1000) ...
# Generating image for seed 379 (378/1000) ...
# Generating image for seed 380 (379/1000) ...
# Generating image for seed 381 (380/1000) ...
# Generating image for seed 382 (381/1000) ...
# Generating image for seed 383 (382/1000) ...
# Generating image for seed 384 (383/1000) ...
# Generating image for seed 385 (384/1000) ...
# Generating image for seed 386 (385/1000) ...
# Generating image for seed 387 (386/1000) ...
# Generating image for seed 388 (387/1000) ...
# Generating image for seed 389 (388/1000) ...
# Generating image for seed 390 (389/1000) ...
# Generating image for seed 391 (390/1000) ...
# Generating image for seed 392 (391/1000) ...
# Generating image for seed 393 (392/1000) ...
# Generating image for seed 394 (393/1000) ...
# Generating image for seed 395 (394/1000) ...
# Generating image for seed 396 (395/1000) ...
# Generating image for seed 397 (396/1000) ...
# Generating image for seed 398 (397/1000) ...
# Generating image for seed 399 (398/1000) ...
# Generating image for seed 400 (399/1000) ...
# Generating image for seed 401 (400/1000) ...
# Generating image for seed 402 (401/1000) ...
# Generating image for seed 403 (402/1000) ...
# Generating image for seed 404 (403/1000) ...
# Generating image for seed 405 (404/1000) ...
# Generating image for seed 406 (405/1000) ...
# Generating image for seed 407 (406/1000) ...
# Generating image for seed 408 (407/1000) ...
# Generating image for seed 409 (408/1000) ...
# Generating image for seed 410 (409/1000) ...
# Generating image for seed 411 (410/1000) ...
# Generating image for seed 412 (411/1000) ...
# Generating image for seed 413 (412/1000) ...
# Generating image for seed 414 (413/1000) ...
# Generating image for seed 415 (414/1000) ...
# Generating image for seed 416 (415/1000) ...
# Generating image for seed 417 (416/1000) ...
# Generating image for seed 418 (417/1000) ...
# Generating image for seed 419 (418/1000) ...
# Generating image for seed 420 (419/1000) ...
# Generating image for seed 421 (420/1000) ...
# Generating image for seed 422 (421/1000) ...
# Generating image for seed 423 (422/1000) ...
# Generating image for seed 424 (423/1000) ...
# Generating image for seed 425 (424/1000) ...
# Generating image for seed 426 (425/1000) ...
# Generating image for seed 427 (426/1000) ...
# Generating image for seed 428 (427/1000) ...
# Generating image for seed 429 (428/1000) ...
# Generating image for seed 430 (429/1000) ...
# Generating image for seed 431 (430/1000) ...
# Generating image for seed 432 (431/1000) ...
# Generating image for seed 433 (432/1000) ...
# Generating image for seed 434 (433/1000) ...
# Generating image for seed 435 (434/1000) ...
# Generating image for seed 436 (435/1000) ...
# Generating image for seed 437 (436/1000) ...
# Generating image for seed 438 (437/1000) ...
# Generating image for seed 439 (438/1000) ...
# Generating image for seed 440 (439/1000) ...
# Generating image for seed 441 (440/1000) ...
# Generating image for seed 442 (441/1000) ...
# Generating image for seed 443 (442/1000) ...
# Generating image for seed 444 (443/1000) ...
# Generating image for seed 445 (444/1000) ...
# Generating image for seed 446 (445/1000) ...
# Generating image for seed 447 (446/1000) ...
# Generating image for seed 448 (447/1000) ...
# Generating image for seed 449 (448/1000) ...
# Generating image for seed 450 (449/1000) ...
# Generating image for seed 451 (450/1000) ...
# Generating image for seed 452 (451/1000) ...
# Generating image for seed 453 (452/1000) ...
# Generating image for seed 454 (453/1000) ...
# Generating image for seed 455 (454/1000) ...
# Generating image for seed 456 (455/1000) ...
# Generating image for seed 457 (456/1000) ...
# Generating image for seed 458 (457/1000) ...
# Generating image for seed 459 (458/1000) ...
# Generating image for seed 460 (459/1000) ...
# Generating image for seed 461 (460/1000) ...
# Generating image for seed 462 (461/1000) ...
# Generating image for seed 463 (462/1000) ...
# Generating image for seed 464 (463/1000) ...
# Generating image for seed 465 (464/1000) ...
# Generating image for seed 466 (465/1000) ...
# Generating image for seed 467 (466/1000) ...
# Generating image for seed 468 (467/1000) ...
# Generating image for seed 469 (468/1000) ...
# Generating image for seed 470 (469/1000) ...
# Generating image for seed 471 (470/1000) ...
# Generating image for seed 472 (471/1000) ...
# Generating image for seed 473 (472/1000) ...
# Generating image for seed 474 (473/1000) ...
# Generating image for seed 475 (474/1000) ...
# Generating image for seed 476 (475/1000) ...
# Generating image for seed 477 (476/1000) ...
# Generating image for seed 478 (477/1000) ...
# Generating image for seed 479 (478/1000) ...
# Generating image for seed 480 (479/1000) ...
# Generating image for seed 481 (480/1000) ...
# Generating image for seed 482 (481/1000) ...
# Generating image for seed 483 (482/1000) ...
# Generating image for seed 484 (483/1000) ...
# Generating image for seed 485 (484/1000) ...
# Generating image for seed 486 (485/1000) ...
# Generating image for seed 487 (486/1000) ...
# Generating image for seed 488 (487/1000) ...
# Generating image for seed 489 (488/1000) ...
# Generating image for seed 490 (489/1000) ...
# Generating image for seed 491 (490/1000) ...
# Generating image for seed 492 (491/1000) ...
# Generating image for seed 493 (492/1000) ...
# Generating image for seed 494 (493/1000) ...
# Generating image for seed 495 (494/1000) ...
# Generating image for seed 496 (495/1000) ...
# Generating image for seed 497 (496/1000) ...
# Generating image for seed 498 (497/1000) ...
# Generating image for seed 499 (498/1000) ...
# Generating image for seed 500 (499/1000) ...
# Generating image for seed 501 (500/1000) ...
# Generating image for seed 502 (501/1000) ...
# Generating image for seed 503 (502/1000) ...
# Generating image for seed 504 (503/1000) ...
# Generating image for seed 505 (504/1000) ...
# Generating image for seed 506 (505/1000) ...
# Generating image for seed 507 (506/1000) ...
# Generating image for seed 508 (507/1000) ...
# Generating image for seed 509 (508/1000) ...
# Generating image for seed 510 (509/1000) ...
# Generating image for seed 511 (510/1000) ...
# Generating image for seed 512 (511/1000) ...
# Generating image for seed 513 (512/1000) ...
# Generating image for seed 514 (513/1000) ...
# Generating image for seed 515 (514/1000) ...
# Generating image for seed 516 (515/1000) ...
# Generating image for seed 517 (516/1000) ...
# Generating image for seed 518 (517/1000) ...
# Generating image for seed 519 (518/1000) ...
# Generating image for seed 520 (519/1000) ...
# Generating image for seed 521 (520/1000) ...
# Generating image for seed 522 (521/1000) ...
# Generating image for seed 523 (522/1000) ...
# Generating image for seed 524 (523/1000) ...
# Generating image for seed 525 (524/1000) ...
# Generating image for seed 526 (525/1000) ...
# Generating image for seed 527 (526/1000) ...
# Generating image for seed 528 (527/1000) ...
# Generating image for seed 529 (528/1000) ...
# Generating image for seed 530 (529/1000) ...
# Generating image for seed 531 (530/1000) ...
# Generating image for seed 532 (531/1000) ...
# Generating image for seed 533 (532/1000) ...
# Generating image for seed 534 (533/1000) ...
# Generating image for seed 535 (534/1000) ...
# Generating image for seed 536 (535/1000) ...
# Generating image for seed 537 (536/1000) ...
# Generating image for seed 538 (537/1000) ...
# Generating image for seed 539 (538/1000) ...
# Generating image for seed 540 (539/1000) ...
# Generating image for seed 541 (540/1000) ...
# Generating image for seed 542 (541/1000) ...
# Generating image for seed 543 (542/1000) ...
# Generating image for seed 544 (543/1000) ...
# Generating image for seed 545 (544/1000) ...
# Generating image for seed 546 (545/1000) ...
# Generating image for seed 547 (546/1000) ...
# Generating image for seed 548 (547/1000) ...
# Generating image for seed 549 (548/1000) ...
# Generating image for seed 550 (549/1000) ...
# Generating image for seed 551 (550/1000) ...
# Generating image for seed 552 (551/1000) ...
# Generating image for seed 553 (552/1000) ...
# Generating image for seed 554 (553/1000) ...
# Generating image for seed 555 (554/1000) ...
# Generating image for seed 556 (555/1000) ...
# Generating image for seed 557 (556/1000) ...
# Generating image for seed 558 (557/1000) ...
# Generating image for seed 559 (558/1000) ...
# Generating image for seed 560 (559/1000) ...
# Generating image for seed 561 (560/1000) ...
# Generating image for seed 562 (561/1000) ...
# Generating image for seed 563 (562/1000) ...
# Generating image for seed 564 (563/1000) ...
# Generating image for seed 565 (564/1000) ...
# Generating image for seed 566 (565/1000) ...
# Generating image for seed 567 (566/1000) ...
# Generating image for seed 568 (567/1000) ...
# Generating image for seed 569 (568/1000) ...
# Generating image for seed 570 (569/1000) ...
# Generating image for seed 571 (570/1000) ...
# Generating image for seed 572 (571/1000) ...
# Generating image for seed 573 (572/1000) ...
# Generating image for seed 574 (573/1000) ...
# Generating image for seed 575 (574/1000) ...
# Generating image for seed 576 (575/1000) ...
# Generating image for seed 577 (576/1000) ...
# Generating image for seed 578 (577/1000) ...
# Generating image for seed 579 (578/1000) ...
# Generating image for seed 580 (579/1000) ...
# Generating image for seed 581 (580/1000) ...
# Generating image for seed 582 (581/1000) ...
# Generating image for seed 583 (582/1000) ...
# Generating image for seed 584 (583/1000) ...
# Generating image for seed 585 (584/1000) ...
# Generating image for seed 586 (585/1000) ...
# Generating image for seed 587 (586/1000) ...
# Generating image for seed 588 (587/1000) ...
# Generating image for seed 589 (588/1000) ...
# Generating image for seed 590 (589/1000) ...
# Generating image for seed 591 (590/1000) ...
# Generating image for seed 592 (591/1000) ...
# Generating image for seed 593 (592/1000) ...
# Generating image for seed 594 (593/1000) ...
# Generating image for seed 595 (594/1000) ...
# Generating image for seed 596 (595/1000) ...
# Generating image for seed 597 (596/1000) ...
# Generating image for seed 598 (597/1000) ...
# Generating image for seed 599 (598/1000) ...
# Generating image for seed 600 (599/1000) ...
# Generating image for seed 601 (600/1000) ...
# Generating image for seed 602 (601/1000) ...
# Generating image for seed 603 (602/1000) ...
# Generating image for seed 604 (603/1000) ...
# Generating image for seed 605 (604/1000) ...
# Generating image for seed 606 (605/1000) ...
# Generating image for seed 607 (606/1000) ...
# Generating image for seed 608 (607/1000) ...
# Generating image for seed 609 (608/1000) ...
# Generating image for seed 610 (609/1000) ...
# Generating image for seed 611 (610/1000) ...
# Generating image for seed 612 (611/1000) ...
# Generating image for seed 613 (612/1000) ...
# Generating image for seed 614 (613/1000) ...
# Generating image for seed 615 (614/1000) ...
# Generating image for seed 616 (615/1000) ...
# Generating image for seed 617 (616/1000) ...
# Generating image for seed 618 (617/1000) ...
# Generating image for seed 619 (618/1000) ...
# Generating image for seed 620 (619/1000) ...
# Generating image for seed 621 (620/1000) ...
# Generating image for seed 622 (621/1000) ...
# Generating image for seed 623 (622/1000) ...
# Generating image for seed 624 (623/1000) ...
# Generating image for seed 625 (624/1000) ...
# Generating image for seed 626 (625/1000) ...
# Generating image for seed 627 (626/1000) ...
# Generating image for seed 628 (627/1000) ...
# Generating image for seed 629 (628/1000) ...
# Generating image for seed 630 (629/1000) ...
# Generating image for seed 631 (630/1000) ...
# Generating image for seed 632 (631/1000) ...
# Generating image for seed 633 (632/1000) ...
# Generating image for seed 634 (633/1000) ...
# Generating image for seed 635 (634/1000) ...
# Generating image for seed 636 (635/1000) ...
# Generating image for seed 637 (636/1000) ...
# Generating image for seed 638 (637/1000) ...
# Generating image for seed 639 (638/1000) ...
# Generating image for seed 640 (639/1000) ...
# Generating image for seed 641 (640/1000) ...
# Generating image for seed 642 (641/1000) ...
# Generating image for seed 643 (642/1000) ...
# Generating image for seed 644 (643/1000) ...
# Generating image for seed 645 (644/1000) ...
# Generating image for seed 646 (645/1000) ...
# Generating image for seed 647 (646/1000) ...
# Generating image for seed 648 (647/1000) ...
# Generating image for seed 649 (648/1000) ...
# Generating image for seed 650 (649/1000) ...
# Generating image for seed 651 (650/1000) ...
# Generating image for seed 652 (651/1000) ...
# Generating image for seed 653 (652/1000) ...
# Generating image for seed 654 (653/1000) ...
# Generating image for seed 655 (654/1000) ...
# Generating image for seed 656 (655/1000) ...
# Generating image for seed 657 (656/1000) ...
# Generating image for seed 658 (657/1000) ...
# Generating image for seed 659 (658/1000) ...
# Generating image for seed 660 (659/1000) ...
# Generating image for seed 661 (660/1000) ...
# Generating image for seed 662 (661/1000) ...
# Generating image for seed 663 (662/1000) ...
# Generating image for seed 664 (663/1000) ...
# Generating image for seed 665 (664/1000) ...
# Generating image for seed 666 (665/1000) ...
# Generating image for seed 667 (666/1000) ...
# Generating image for seed 668 (667/1000) ...
# Generating image for seed 669 (668/1000) ...
# Generating image for seed 670 (669/1000) ...
# Generating image for seed 671 (670/1000) ...
# Generating image for seed 672 (671/1000) ...
# Generating image for seed 673 (672/1000) ...
# Generating image for seed 674 (673/1000) ...
# Generating image for seed 675 (674/1000) ...
# Generating image for seed 676 (675/1000) ...
# Generating image for seed 677 (676/1000) ...
# Generating image for seed 678 (677/1000) ...
# Generating image for seed 679 (678/1000) ...
# Generating image for seed 680 (679/1000) ...
# Generating image for seed 681 (680/1000) ...
# Generating image for seed 682 (681/1000) ...
# Generating image for seed 683 (682/1000) ...
# Generating image for seed 684 (683/1000) ...
# Generating image for seed 685 (684/1000) ...
# Generating image for seed 686 (685/1000) ...
# Generating image for seed 687 (686/1000) ...
# Generating image for seed 688 (687/1000) ...
# Generating image for seed 689 (688/1000) ...
# Generating image for seed 690 (689/1000) ...
# Generating image for seed 691 (690/1000) ...
# Generating image for seed 692 (691/1000) ...
# Generating image for seed 693 (692/1000) ...
# Generating image for seed 694 (693/1000) ...
# Generating image for seed 695 (694/1000) ...
# Generating image for seed 696 (695/1000) ...
# Generating image for seed 697 (696/1000) ...
# Generating image for seed 698 (697/1000) ...
# Generating image for seed 699 (698/1000) ...
# Generating image for seed 700 (699/1000) ...
# Generating image for seed 701 (700/1000) ...
# Generating image for seed 702 (701/1000) ...
# Generating image for seed 703 (702/1000) ...
# Generating image for seed 704 (703/1000) ...
# Generating image for seed 705 (704/1000) ...
# Generating image for seed 706 (705/1000) ...
# Generating image for seed 707 (706/1000) ...
# Generating image for seed 708 (707/1000) ...
# Generating image for seed 709 (708/1000) ...
# Generating image for seed 710 (709/1000) ...
# Generating image for seed 711 (710/1000) ...
# Generating image for seed 712 (711/1000) ...
# Generating image for seed 713 (712/1000) ...
# Generating image for seed 714 (713/1000) ...
# Generating image for seed 715 (714/1000) ...
# Generating image for seed 716 (715/1000) ...
# Generating image for seed 717 (716/1000) ...
# Generating image for seed 718 (717/1000) ...
# Generating image for seed 719 (718/1000) ...
# Generating image for seed 720 (719/1000) ...
# Generating image for seed 721 (720/1000) ...
# Generating image for seed 722 (721/1000) ...
# Generating image for seed 723 (722/1000) ...
# Generating image for seed 724 (723/1000) ...
# Generating image for seed 725 (724/1000) ...
# Generating image for seed 726 (725/1000) ...
# Generating image for seed 727 (726/1000) ...
# Generating image for seed 728 (727/1000) ...
# Generating image for seed 729 (728/1000) ...
# Generating image for seed 730 (729/1000) ...
# Generating image for seed 731 (730/1000) ...
# Generating image for seed 732 (731/1000) ...
# Generating image for seed 733 (732/1000) ...
# Generating image for seed 734 (733/1000) ...
# Generating image for seed 735 (734/1000) ...
# Generating image for seed 736 (735/1000) ...
# Generating image for seed 737 (736/1000) ...
# Generating image for seed 738 (737/1000) ...
# Generating image for seed 739 (738/1000) ...
# Generating image for seed 740 (739/1000) ...
# Generating image for seed 741 (740/1000) ...
# Generating image for seed 742 (741/1000) ...
# Generating image for seed 743 (742/1000) ...
# Generating image for seed 744 (743/1000) ...
# Generating image for seed 745 (744/1000) ...
# Generating image for seed 746 (745/1000) ...
# Generating image for seed 747 (746/1000) ...
# Generating image for seed 748 (747/1000) ...
# Generating image for seed 749 (748/1000) ...
# Generating image for seed 750 (749/1000) ...
# Generating image for seed 751 (750/1000) ...
# Generating image for seed 752 (751/1000) ...
# Generating image for seed 753 (752/1000) ...
# Generating image for seed 754 (753/1000) ...
# Generating image for seed 755 (754/1000) ...
# Generating image for seed 756 (755/1000) ...
# Generating image for seed 757 (756/1000) ...
# Generating image for seed 758 (757/1000) ...
# Generating image for seed 759 (758/1000) ...
# Generating image for seed 760 (759/1000) ...
# Generating image for seed 761 (760/1000) ...
# Generating image for seed 762 (761/1000) ...
# Generating image for seed 763 (762/1000) ...
# Generating image for seed 764 (763/1000) ...
# Generating image for seed 765 (764/1000) ...
# Generating image for seed 766 (765/1000) ...
# Generating image for seed 767 (766/1000) ...
# Generating image for seed 768 (767/1000) ...
# Generating image for seed 769 (768/1000) ...
# Generating image for seed 770 (769/1000) ...
# Generating image for seed 771 (770/1000) ...
# Generating image for seed 772 (771/1000) ...
# Generating image for seed 773 (772/1000) ...
# Generating image for seed 774 (773/1000) ...
# Generating image for seed 775 (774/1000) ...
# Generating image for seed 776 (775/1000) ...
# Generating image for seed 777 (776/1000) ...
# Generating image for seed 778 (777/1000) ...
# Generating image for seed 779 (778/1000) ...
# Generating image for seed 780 (779/1000) ...
# Generating image for seed 781 (780/1000) ...
# Generating image for seed 782 (781/1000) ...
# Generating image for seed 783 (782/1000) ...
# Generating image for seed 784 (783/1000) ...
# Generating image for seed 785 (784/1000) ...
# Generating image for seed 786 (785/1000) ...
# Generating image for seed 787 (786/1000) ...
# Generating image for seed 788 (787/1000) ...
# Generating image for seed 789 (788/1000) ...
# Generating image for seed 790 (789/1000) ...
# Generating image for seed 791 (790/1000) ...
# Generating image for seed 792 (791/1000) ...
# Generating image for seed 793 (792/1000) ...
# Generating image for seed 794 (793/1000) ...
# Generating image for seed 795 (794/1000) ...
# Generating image for seed 796 (795/1000) ...
# Generating image for seed 797 (796/1000) ...
# Generating image for seed 798 (797/1000) ...
# Generating image for seed 799 (798/1000) ...
# Generating image for seed 800 (799/1000) ...
# Generating image for seed 801 (800/1000) ...
# Generating image for seed 802 (801/1000) ...
# Generating image for seed 803 (802/1000) ...
# Generating image for seed 804 (803/1000) ...
# Generating image for seed 805 (804/1000) ...
# Generating image for seed 806 (805/1000) ...
# Generating image for seed 807 (806/1000) ...
# Generating image for seed 808 (807/1000) ...
# Generating image for seed 809 (808/1000) ...
# Generating image for seed 810 (809/1000) ...
# Generating image for seed 811 (810/1000) ...
# Generating image for seed 812 (811/1000) ...
# Generating image for seed 813 (812/1000) ...
# Generating image for seed 814 (813/1000) ...
# Generating image for seed 815 (814/1000) ...
# Generating image for seed 816 (815/1000) ...
# Generating image for seed 817 (816/1000) ...
# Generating image for seed 818 (817/1000) ...
# Generating image for seed 819 (818/1000) ...
# Generating image for seed 820 (819/1000) ...
# Generating image for seed 821 (820/1000) ...
# Generating image for seed 822 (821/1000) ...
# Generating image for seed 823 (822/1000) ...
# Generating image for seed 824 (823/1000) ...
# Generating image for seed 825 (824/1000) ...
# Generating image for seed 826 (825/1000) ...
# Generating image for seed 827 (826/1000) ...
# Generating image for seed 828 (827/1000) ...
# Generating image for seed 829 (828/1000) ...
# Generating image for seed 830 (829/1000) ...
# Generating image for seed 831 (830/1000) ...
# Generating image for seed 832 (831/1000) ...
# Generating image for seed 833 (832/1000) ...
# Generating image for seed 834 (833/1000) ...
# Generating image for seed 835 (834/1000) ...
# Generating image for seed 836 (835/1000) ...
# Generating image for seed 837 (836/1000) ...
# Generating image for seed 838 (837/1000) ...
# Generating image for seed 839 (838/1000) ...
# Generating image for seed 840 (839/1000) ...
# Generating image for seed 841 (840/1000) ...
# Generating image for seed 842 (841/1000) ...
# Generating image for seed 843 (842/1000) ...
# Generating image for seed 844 (843/1000) ...
# Generating image for seed 845 (844/1000) ...
# Generating image for seed 846 (845/1000) ...
# Generating image for seed 847 (846/1000) ...
# Generating image for seed 848 (847/1000) ...
# Generating image for seed 849 (848/1000) ...
# Generating image for seed 850 (849/1000) ...
# Generating image for seed 851 (850/1000) ...
# Generating image for seed 852 (851/1000) ...
# Generating image for seed 853 (852/1000) ...
# Generating image for seed 854 (853/1000) ...
# Generating image for seed 855 (854/1000) ...
# Generating image for seed 856 (855/1000) ...
# Generating image for seed 857 (856/1000) ...
# Generating image for seed 858 (857/1000) ...
# Generating image for seed 859 (858/1000) ...
# Generating image for seed 860 (859/1000) ...
# Generating image for seed 861 (860/1000) ...
# Generating image for seed 862 (861/1000) ...
# Generating image for seed 863 (862/1000) ...
# Generating image for seed 864 (863/1000) ...
# Generating image for seed 865 (864/1000) ...
# Generating image for seed 866 (865/1000) ...
# Generating image for seed 867 (866/1000) ...
# Generating image for seed 868 (867/1000) ...
# Generating image for seed 869 (868/1000) ...
# Generating image for seed 870 (869/1000) ...
# Generating image for seed 871 (870/1000) ...
# Generating image for seed 872 (871/1000) ...
# Generating image for seed 873 (872/1000) ...
# Generating image for seed 874 (873/1000) ...
# Generating image for seed 875 (874/1000) ...
# Generating image for seed 876 (875/1000) ...
# Generating image for seed 877 (876/1000) ...
# Generating image for seed 878 (877/1000) ...
# Generating image for seed 879 (878/1000) ...
# Generating image for seed 880 (879/1000) ...
# Generating image for seed 881 (880/1000) ...
# Generating image for seed 882 (881/1000) ...
# Generating image for seed 883 (882/1000) ...
# Generating image for seed 884 (883/1000) ...
# Generating image for seed 885 (884/1000) ...
# Generating image for seed 886 (885/1000) ...
# Generating image for seed 887 (886/1000) ...
# Generating image for seed 888 (887/1000) ...
# Generating image for seed 889 (888/1000) ...
# Generating image for seed 890 (889/1000) ...
# Generating image for seed 891 (890/1000) ...
# Generating image for seed 892 (891/1000) ...
# Generating image for seed 893 (892/1000) ...
# Generating image for seed 894 (893/1000) ...
# Generating image for seed 895 (894/1000) ...
# Generating image for seed 896 (895/1000) ...
# Generating image for seed 897 (896/1000) ...
# Generating image for seed 898 (897/1000) ...
# Generating image for seed 899 (898/1000) ...
# Generating image for seed 900 (899/1000) ...
# Generating image for seed 901 (900/1000) ...
# Generating image for seed 902 (901/1000) ...
# Generating image for seed 903 (902/1000) ...
# Generating image for seed 904 (903/1000) ...
# Generating image for seed 905 (904/1000) ...
# Generating image for seed 906 (905/1000) ...
# Generating image for seed 907 (906/1000) ...
# Generating image for seed 908 (907/1000) ...
# Generating image for seed 909 (908/1000) ...
# Generating image for seed 910 (909/1000) ...
# Generating image for seed 911 (910/1000) ...
# Generating image for seed 912 (911/1000) ...
# Generating image for seed 913 (912/1000) ...
# Generating image for seed 914 (913/1000) ...
# Generating image for seed 915 (914/1000) ...
# Generating image for seed 916 (915/1000) ...
# Generating image for seed 917 (916/1000) ...
# Generating image for seed 918 (917/1000) ...
# Generating image for seed 919 (918/1000) ...
# Generating image for seed 920 (919/1000) ...
# Generating image for seed 921 (920/1000) ...
# Generating image for seed 922 (921/1000) ...
# Generating image for seed 923 (922/1000) ...
# Generating image for seed 924 (923/1000) ...
# Generating image for seed 925 (924/1000) ...
# Generating image for seed 926 (925/1000) ...
# Generating image for seed 927 (926/1000) ...
# Generating image for seed 928 (927/1000) ...
# Generating image for seed 929 (928/1000) ...
# Generating image for seed 930 (929/1000) ...
# Generating image for seed 931 (930/1000) ...
# Generating image for seed 932 (931/1000) ...
# Generating image for seed 933 (932/1000) ...
# Generating image for seed 934 (933/1000) ...
# Generating image for seed 935 (934/1000) ...
# Generating image for seed 936 (935/1000) ...
# Generating image for seed 937 (936/1000) ...
# Generating image for seed 938 (937/1000) ...
# Generating image for seed 939 (938/1000) ...
# Generating image for seed 940 (939/1000) ...
# Generating image for seed 941 (940/1000) ...
# Generating image for seed 942 (941/1000) ...
# Generating image for seed 943 (942/1000) ...
# Generating image for seed 944 (943/1000) ...
# Generating image for seed 945 (944/1000) ...
# Generating image for seed 946 (945/1000) ...
# Generating image for seed 947 (946/1000) ...
# Generating image for seed 948 (947/1000) ...
# Generating image for seed 949 (948/1000) ...
# Generating image for seed 950 (949/1000) ...
# Generating image for seed 951 (950/1000) ...
# Generating image for seed 952 (951/1000) ...
# Generating image for seed 953 (952/1000) ...
# Generating image for seed 954 (953/1000) ...
# Generating image for seed 955 (954/1000) ...
# Generating image for seed 956 (955/1000) ...
# Generating image for seed 957 (956/1000) ...
# Generating image for seed 958 (957/1000) ...
# Generating image for seed 959 (958/1000) ...
# Generating image for seed 960 (959/1000) ...
# Generating image for seed 961 (960/1000) ...
# Generating image for seed 962 (961/1000) ...
# Generating image for seed 963 (962/1000) ...
# Generating image for seed 964 (963/1000) ...
# Generating image for seed 965 (964/1000) ...
# Generating image for seed 966 (965/1000) ...
# Generating image for seed 967 (966/1000) ...
# Generating image for seed 968 (967/1000) ...
# Generating image for seed 969 (968/1000) ...
# Generating image for seed 970 (969/1000) ...
# Generating image for seed 971 (970/1000) ...
# Generating image for seed 972 (971/1000) ...
# Generating image for seed 973 (972/1000) ...
# Generating image for seed 974 (973/1000) ...
# Generating image for seed 975 (974/1000) ...
# Generating image for seed 976 (975/1000) ...
# Generating image for seed 977 (976/1000) ...
# Generating image for seed 978 (977/1000) ...
# Generating image for seed 979 (978/1000) ...
# Generating image for seed 980 (979/1000) ...
# Generating image for seed 981 (980/1000) ...
# Generating image for seed 982 (981/1000) ...
# Generating image for seed 983 (982/1000) ...
# Generating image for seed 984 (983/1000) ...
# Generating image for seed 985 (984/1000) ...
# Generating image for seed 986 (985/1000) ...
# Generating image for seed 987 (986/1000) ...
# Generating image for seed 988 (987/1000) ...
# Generating image for seed 989 (988/1000) ...
# Generating image for seed 990 (989/1000) ...
# Generating image for seed 991 (990/1000) ...
# Generating image for seed 992 (991/1000) ...
# Generating image for seed 993 (992/1000) ...
# Generating image for seed 994 (993/1000) ...
# Generating image for seed 995 (994/1000) ...
# Generating image for seed 996 (995/1000) ...
# Generating image for seed 997 (996/1000) ...
# Generating image for seed 998 (997/1000) ...
# Generating image for seed 999 (998/1000) ...
# Generating image for seed 1000 (999/1000) ...

# %% [markdown]
# # Graph StyleGAN model metrics

# %%
# Import JSON
import json
import matplotlib.pyplot as plt

# %%
def load_jsonl(filepath):
    '''Load jsonl file from provided fielpath and return data'''
    data = []
    with open(filepath, 'r') as f:
        for line in f:
            data.append(json.loads(line.strip()))
    return data

def graph_stats(statsFile, className):
    ''' Graph StyleGAN fine-tuning statistics from training

    Parameters:
    - statsFile:  Stats file data
    - className:  String indicating Class Name used for Plot Title'''
    
    # Extract values over time
    iterations = [entry['Progress/kimg']['mean'] for entry in statsFile]
    
    # Important metrics to plot
    metrics = [
        'Loss/G/loss',
        'Loss/D/loss',
        'Loss/pl_penalty',
        'Loss/r1_penalty',
        'Loss/scores/fake',
        'Loss/scores/real'
    ]
    
    # Plotting
    plt.figure(figsize=(14, 8))
    
    for metric in metrics:
        values = [entry[metric]['mean'] for entry in statsFile]
        plt.plot(iterations, values, label=metric)
    
    plt.xlabel('Training Progress (per thousand images)')
    plt.ylabel('Metric Values')
    plt.title(f'StyleGAN Fine-Tuning for {className} Images - Statistics')
    plt.legend(loc='upper right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Load Normal training stats and graph them
normal_stats = load_jsonl('./data/chest_xray/gen/output/normal/stats.jsonl')
graph_stats(normal_stats, 'Normal')

# %%
# Load Pneumonia training stats and graph them
pneumonia_stats = load_jsonl('./data/chest_xray/gen/output/pneumonia/stats.jsonl')
graph_stats(normal_stats, 'Pneumonia')
