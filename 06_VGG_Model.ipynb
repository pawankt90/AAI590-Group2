# %%
from google.colab import drive
import sys

# Mount Google Drive
drive.mount('/content/drive')

# Add the folder containing data_utils.py to the system path
sys.path.append('/content/drive/MyDrive/data')
# Out:
# Mounted at /content/drive

# %%
# --- Standard Libraries ---
import os
import cv2
import sys
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Scikit-learn ---
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# --- TensorFlow / Keras ---
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

# --- Custom Utilities ---
from data_utils import (
    load_sample_dataframe_from_dir,
    load_dataset_from_df,
    load_dataset_from_dir,
    balance_data
)

# %% [markdown]
# ## Create VGG Model

# %%
# Function to create VGG Model
def create_vgg_model(input_shape, num_classes):

  # Load the pre-trained VGG16 model (without the top layer)
  vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

  # Freeze all layers except the last few
  for layer in vgg_base.layers[:-4]:
      layer.trainable = False

  # Add a custom classification head
  x = Flatten()(vgg_base.output)
  x = Dense(256, activation='relu')(x)
  x = Dropout(0.5)(x)
  x = Dense(1, activation='sigmoid')(x)  # Binary classification (Normal vs. Pneumonia)

  # Create the model
  model = Model(inputs=vgg_base.input, outputs=x)

  # Compile the model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                loss='binary_crossentropy',
                metrics=['accuracy', 'precision', 'recall'])
  return model

# %%
num_epochs = 30

def train_and_evaluate(model, train_ds, val_ds, test_ds, test_description="example_test"):
    results_path = f"{test_description}_results.csv"

    # Callbacks for training
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=5, verbose=1)

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=num_epochs,
        callbacks=[lr_scheduler, early_stopping]
    )

    # Reset test_ds if applicable
    if hasattr(test_ds, 'reset'):
        test_ds.reset()

    # Predictions (fixed to go through test set exactly once)
    y_true, y_pred = [], []
    steps = test_ds.samples // test_ds.batch_size
    if test_ds.samples % test_ds.batch_size != 0:
        steps += 1

    for i in range(steps):
        images, labels = next(test_ds)
        predictions = model.predict(images, verbose=0)
        binary_preds = (predictions > 0.6).astype(int).flatten()
        y_true.extend(labels.astype(int))
        y_pred.extend(binary_preds)

    # Metrics
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    report = classification_report(y_true, y_pred, output_dict=True)
    class_0_precision = report['0']['precision']
    class_0_recall = report['0']['recall']
    class_1_precision = report['1']['precision']
    class_1_recall = report['1']['recall']

    results_df = pd.DataFrame({
        'Accuracy': [accuracy],
        'Precision': [precision],
        'Recall': [recall],
        'F1 Score': [f1],
        'Class_0_Precision': [class_0_precision],
        'Class_0_Recall': [class_0_recall],
        'Class_1_Precision': [class_1_precision],
        'Class_1_Recall': [class_1_recall]
    })

    results_df.to_csv(results_path, index=False)
    print("Metrics saved to", results_path)
    print(classification_report(y_true, y_pred))
    return history, y_true, y_pred, results_df

# %%
# Function to visualize results
def plot_results(history, y_true, y_pred, test_description):
    # accuracy metric
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.legend()
    plt.title('Training & Validation Accuracy')
    plt.savefig(f"{test_description}_accuracy.png")

    # loss function
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.legend()
    plt.title('Training & Validation Loss')
    plt.savefig(f"{test_description}_loss.png")

    # recall metric
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['recall'], label='Train Recall')
    plt.plot(history.history['val_recall'], label='Val Recall')
    plt.legend()
    plt.title('Training & Validation Recall')
    plt.savefig(f"{test_description}_recall.png")

    plt.show()

# %% [markdown]
# ## Load Data

# %%
model = create_vgg_model(input_shape=(128, 128, 3), num_classes=2)
model.save("vgg16_chest_xray.keras")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# ## Base Real Images

# %%
# Use Kaggle data as base

# --- Paths ---
normal_data_path = '/content/drive/MyDrive/data/chest_xray/train/NORMAL'
pneumonia_data_path = '/content/drive/MyDrive/data/chest_xray/train/PNEUMONIA'
test_data_path = '/content/drive/MyDrive/data/chest_xray/test'

# --- Build and split DataFrames ---
train_df = pd.DataFrame(columns=['filename', 'class'])
train_df = load_sample_dataframe_from_dir(train_df, normal_data_path, 'NORMAL', sample_size=1341, seed=42)
train_df = load_sample_dataframe_from_dir(train_df, pneumonia_data_path, 'PNEUMONIA', sample_size=3875, seed=42)

# Stratified train/val split
search_df, val_df = train_test_split(train_df, test_size=0.2, stratify=train_df['class'], random_state=42)

# --- Create datasets ---
search_ds = load_dataset_from_df(search_df, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')
val_ds = load_dataset_from_df(val_df, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')
test_ds = load_dataset_from_dir(test_data_path, img_size=(128, 128), batch_size=32, gaussian_blur=False, color_mode='rgb')
# Out:
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Evaluate the best model from the tuner
test_description = "vgg_cnn_vanilla"

history, y_true, y_pred, results_df = train_and_evaluate(
    model=model,
    train_ds=search_ds,
    val_ds=val_ds,
    test_ds=test_ds,
    test_description=test_description
)

plot_results(history, y_true, y_pred, test_description)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 947s 7s/step - accuracy: 0.8739 - loss: 0.2741 - precision: 0.9094 - recall: 0.9246 - val_accuracy: 0.9655 - val_loss: 0.0854 - val_precision: 0.9830 - val_recall: 0.9704 - learning_rate: 1.0000e-04
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 75s 572ms/step - accuracy: 0.9741 - loss: 0.0768 - precision: 0.9849 - recall: 0.9803 - val_accuracy: 0.9780 - val_loss: 0.0640 - val_precision: 0.9748 - val_recall: 0.9961 - learning_rate: 1.0000e-04
# Epoch 3/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 75s 570ms/step - accuracy: 0.9831 - loss: 0.0491 - precision: 0.9900 - recall: 0.9872 - val_accuracy: 0.9789 - val_loss: 0.0678 - val_precision: 0.9961 - val_recall: 0.9755 - learning_rate: 1.0000e-04
# Epoch 4/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 74s 564ms/step - accuracy: 0.9860 - loss: 0.0373 - precision: 0.9917 - recall: 0.9898 - val_accuracy: 0.9856 - val_loss: 0.0572 - val_precision: 0.9823 - val_recall: 0.9987 - learning_rate: 1.0000e-04
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 74s 562ms/step - accuracy: 0.9805 - loss: 0.0551 - precision: 0.9859 - recall: 0.9881 - val_accuracy: 0.9837 - val_loss: 0.0651 - val_precision: 0.9822 - val_recall: 0.9961 - learning_rate: 1.0000e-04
# Epoch 6/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 74s 566ms/step - accuracy: 0.9866 - loss: 0.0344 - precision: 0.9901 - recall: 0.9921 - val_accuracy: 0.9818 - val_loss: 0.0447 - val_precision: 0.9909 - val_recall: 0.9845 - learning_rate: 1.0000e-04
# Epoch 7/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 74s 564ms/step - accuracy: 0.9888 - loss: 0.0331 - precision: 0.9919 - recall: 0.9930 - val_accuracy: 0.9789 - val_loss: 0.0577 - val_precision: 0.9961 - val_recall: 0.9755 - learning_rate: 1.0000e-04
# Epoch 8/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 74s 567ms/step - accuracy: 0.9944 - loss: 0.0182 - precision: 0.9966 - recall: 0.9959 - val_accuracy: 0.9713 - val_loss: 0.1346 - val_precision: 0.9663 - val_recall: 0.9961 - learning_rate: 1.0000e-04
# Epoch 9/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 73s 561ms/step - accuracy: 0.9905 - loss: 0.0261 - precision: 0.9934 - recall: 0.9939 - val_accuracy: 0.9856 - val_loss: 0.0452 - val_precision: 0.9910 - val_recall: 0.9897 - learning_rate: 1.0000e-04
# Epoch 10/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 74s 563ms/step - accuracy: 0.9942 - loss: 0.0156 - precision: 0.9951 - recall: 0.9971 - val_accuracy: 0.9799 - val_loss: 0.0642 - val_precision: 0.9896 - val_recall: 0.9832 - learning_rate: 1.0000e-04
# Epoch 11/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9953 - loss: 0.0141 - precision: 0.9971 - recall: 0.9965
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 73s 560ms/step - accuracy: 0.9953 - loss: 0.0141 - precision: 0.9971 - recall: 0.9965 - val_accuracy: 0.9818 - val_loss: 0.0458 - val_precision: 0.9871 - val_recall: 0.9884 - learning_rate: 1.0000e-04
# Metrics saved to vgg_cnn_vanilla_results.csv
#               precision    recall  f1-score   support
#
#            0       0.98      0.44      0.60       234
#            1       0.75      0.99      0.85       390
#
#     accuracy                           0.79       624
#    macro avg       0.86      0.72      0.73       624
# weighted avg       0.83      0.79      0.76       624

# %% [markdown]
# ## Balanced Real Images

# %%
# Balance the training data
balanced_train_df = balance_data('/content/drive/MyDrive/data/chest_xray/train')

# Split into new search/val sets
search_df_bal, val_df_bal = train_test_split(
    balanced_train_df,
    test_size=0.2,
    stratify=balanced_train_df['class'],
    random_state=42
)

# Create balanced datasets
train_ds_bal = search_ds_bal = load_dataset_from_df(search_df_bal, "filename", "class", img_size=(128, 128), batch_size=32,color_mode='rgb')
val_ds_bal = load_dataset_from_df(val_df_bal, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')

# Evaluate best model on balanced data
test_description = "tuned_cnn_vgg_balanced"

history_bal, y_true_bal, y_pred_bal, results_df_bal = train_and_evaluate(
    model=model,
    train_ds=train_ds_bal,
    val_ds=val_ds_bal,
    test_ds=test_ds,
    test_description=test_description
)

plot_results(history_bal, y_true_bal, y_pred_bal, test_description)
# Out:
# Found 2145 validated image filenames belonging to 2 classes.
# Found 537 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 56s 819ms/step - accuracy: 0.9957 - loss: 0.0138 - precision: 0.9942 - recall: 0.9973 - val_accuracy: 0.9963 - val_loss: 0.0094 - val_precision: 1.0000 - val_recall: 0.9925 - learning_rate: 3.0000e-05
# Epoch 2/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 48s 701ms/step - accuracy: 0.9963 - loss: 0.0102 - precision: 0.9973 - recall: 0.9953 - val_accuracy: 0.9963 - val_loss: 0.0102 - val_precision: 0.9963 - val_recall: 0.9963 - learning_rate: 3.0000e-05
# Epoch 3/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 48s 702ms/step - accuracy: 0.9987 - loss: 0.0066 - precision: 0.9995 - recall: 0.9978 - val_accuracy: 0.9944 - val_loss: 0.0138 - val_precision: 1.0000 - val_recall: 0.9888 - learning_rate: 3.0000e-05
# Epoch 4/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 47s 691ms/step - accuracy: 0.9994 - loss: 0.0035 - precision: 1.0000 - recall: 0.9987 - val_accuracy: 0.9907 - val_loss: 0.0179 - val_precision: 0.9817 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Epoch 5/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 47s 691ms/step - accuracy: 0.9966 - loss: 0.0062 - precision: 0.9952 - recall: 0.9978 - val_accuracy: 0.9944 - val_loss: 0.0127 - val_precision: 1.0000 - val_recall: 0.9888 - learning_rate: 3.0000e-05
# Epoch 6/30
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.9998 - loss: 0.0032 - precision: 0.9998 - recall: 0.9998
# Epoch 6: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 47s 687ms/step - accuracy: 0.9997 - loss: 0.0033 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9888 - val_loss: 0.0318 - val_precision: 0.9781 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Metrics saved to tuned_cnn_balanced_results.csv
#               precision    recall  f1-score   support
#
#            0       0.98      0.52      0.68       234
#            1       0.78      0.99      0.87       390
#
#     accuracy                           0.82       624
#    macro avg       0.88      0.76      0.78       624
# weighted avg       0.85      0.82      0.80       624

# %% [markdown]
# ## ACGAN Test

# %%
# --- Paths ---
acgan_data_path = '/content/drive/MyDrive/data/ACGAN'
test_data_path = '/content/drive/MyDrive/data/chest_xray/test'

# --- Build full dataframe from ACGAN synthetic data ---
acgan_df = balance_data(acgan_data_path)  # Balanced already (1000 each, just standardizing flow)

# --- Split into train and val ---
train_df_acgan, val_df_acgan = train_test_split(
    acgan_df,
    test_size=0.2,
    stratify=acgan_df['class'],
    random_state=42
)

# --- Create datasets ---
train_ds_acgan = load_dataset_from_df(train_df_acgan, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')
val_ds_acgan = load_dataset_from_df(val_df_acgan, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')
test_ds = load_dataset_from_dir(test_data_path, img_size=(128, 128), batch_size=32, gaussian_blur=False, color_mode='rgb')
# Out:
# Found 1600 validated image filenames belonging to 2 classes.
# Found 400 validated image filenames belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Train and evaluate using synthetic (ACGAN) training data
test_description = "tuned_cnn_vgg_acgan"

history_acgan, y_true_acgan, y_pred_acgan, results_df_acgan = train_and_evaluate(
    model=model,
    train_ds=train_ds_acgan,
    val_ds=val_ds_acgan,
    test_ds=test_ds,
    test_description=test_description
)

plot_results(history_acgan, y_true_acgan, y_pred_acgan, test_description)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 320ms/step - accuracy: 0.7085 - loss: 0.5177 - precision: 0.6988 - recall: 0.7312 - val_accuracy: 0.9425 - val_loss: 0.1488 - val_precision: 0.9155 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 2/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 294ms/step - accuracy: 0.9530 - loss: 0.1367 - precision: 0.9375 - recall: 0.9699 - val_accuracy: 0.9450 - val_loss: 0.1378 - val_precision: 0.9890 - val_recall: 0.9000 - learning_rate: 1.0000e-04
# Epoch 3/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 286ms/step - accuracy: 0.9460 - loss: 0.1306 - precision: 0.9407 - recall: 0.9476 - val_accuracy: 0.9775 - val_loss: 0.0849 - val_precision: 0.9569 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 282ms/step - accuracy: 0.9820 - loss: 0.0524 - precision: 0.9775 - recall: 0.9880 - val_accuracy: 0.9825 - val_loss: 0.0503 - val_precision: 0.9898 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 5/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 287ms/step - accuracy: 0.9845 - loss: 0.0432 - precision: 0.9814 - recall: 0.9875 - val_accuracy: 0.9725 - val_loss: 0.0731 - val_precision: 0.9522 - val_recall: 0.9950 - learning_rate: 1.0000e-04
# Epoch 6/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 282ms/step - accuracy: 0.9858 - loss: 0.0342 - precision: 0.9811 - recall: 0.9904 - val_accuracy: 0.9625 - val_loss: 0.1028 - val_precision: 0.9384 - val_recall: 0.9900 - learning_rate: 1.0000e-04
# Epoch 7/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 291ms/step - accuracy: 0.9868 - loss: 0.0352 - precision: 0.9837 - recall: 0.9898 - val_accuracy: 0.9900 - val_loss: 0.0485 - val_precision: 0.9804 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 8/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 286ms/step - accuracy: 0.9956 - loss: 0.0131 - precision: 0.9912 - recall: 1.0000 - val_accuracy: 0.9800 - val_loss: 0.0493 - val_precision: 0.9898 - val_recall: 0.9700 - learning_rate: 1.0000e-04
# Epoch 9/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 286ms/step - accuracy: 0.9959 - loss: 0.0133 - precision: 0.9970 - recall: 0.9949 - val_accuracy: 0.9925 - val_loss: 0.0339 - val_precision: 0.9900 - val_recall: 0.9950 - learning_rate: 1.0000e-04
# Epoch 10/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 281ms/step - accuracy: 0.9841 - loss: 0.0359 - precision: 0.9853 - recall: 0.9826 - val_accuracy: 0.9800 - val_loss: 0.0467 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 1.0000e-04
# Epoch 11/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 286ms/step - accuracy: 0.9954 - loss: 0.0118 - precision: 0.9929 - recall: 0.9980 - val_accuracy: 0.9850 - val_loss: 0.0423 - val_precision: 0.9709 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 12/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 282ms/step - accuracy: 0.9994 - loss: 0.0032 - precision: 0.9989 - recall: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.0635 - val_precision: 0.9756 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 13/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 279ms/step - accuracy: 1.0000 - loss: 0.0017 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9900 - val_loss: 0.0305 - val_precision: 0.9900 - val_recall: 0.9900 - learning_rate: 1.0000e-04
# Epoch 14/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 283ms/step - accuracy: 0.9974 - loss: 0.0082 - precision: 0.9995 - recall: 0.9954 - val_accuracy: 0.9500 - val_loss: 0.1636 - val_precision: 0.9091 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 15/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 283ms/step - accuracy: 0.9666 - loss: 0.0896 - precision: 0.9574 - recall: 0.9757 - val_accuracy: 0.9700 - val_loss: 0.0959 - val_precision: 0.9476 - val_recall: 0.9950 - learning_rate: 1.0000e-04
# Epoch 16/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 287ms/step - accuracy: 0.9972 - loss: 0.0102 - precision: 0.9939 - recall: 1.0000 - val_accuracy: 0.9925 - val_loss: 0.0298 - val_precision: 0.9950 - val_recall: 0.9900 - learning_rate: 1.0000e-04
# Epoch 17/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 286ms/step - accuracy: 1.0000 - loss: 8.7029e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.0449 - val_precision: 0.9899 - val_recall: 0.9850 - learning_rate: 1.0000e-04
# Epoch 18/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 284ms/step - accuracy: 1.0000 - loss: 9.8203e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9850 - val_loss: 0.0496 - val_precision: 0.9802 - val_recall: 0.9900 - learning_rate: 1.0000e-04
# Epoch 19/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 285ms/step - accuracy: 1.0000 - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.0313 - val_precision: 0.9851 - val_recall: 0.9900 - learning_rate: 1.0000e-04
# Epoch 20/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 286ms/step - accuracy: 1.0000 - loss: 3.4258e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9800 - val_loss: 0.0452 - val_precision: 0.9752 - val_recall: 0.9850 - learning_rate: 1.0000e-04
# Epoch 21/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9973 - loss: 0.0064 - precision: 0.9980 - recall: 0.9966
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 283ms/step - accuracy: 0.9974 - loss: 0.0063 - precision: 0.9980 - recall: 0.9967 - val_accuracy: 0.9900 - val_loss: 0.0429 - val_precision: 0.9949 - val_recall: 0.9850 - learning_rate: 1.0000e-04
# Metrics saved to tuned_cnn_acgan_results.csv
#               precision    recall  f1-score   support
#
#            0       0.67      0.95      0.79       234
#            1       0.96      0.73      0.83       390
#
#     accuracy                           0.81       624
#    macro avg       0.82      0.84      0.81       624
# weighted avg       0.85      0.81      0.81       624

# %% [markdown]
# ## Style GAN

# %%
# --- Paths ---
stylegan_data_path = '/content/drive/MyDrive/data/STYLEGAN'
test_data_path = '/content/drive/MyDrive/data/chest_xray/test'

# --- Build full dataframe from STYLEGAN synthetic data ---
stylegan_df = balance_data(stylegan_data_path)

# --- Split into train and val ---
train_df_stylegan, val_df_stylegan = train_test_split(
    stylegan_df,
    test_size=0.2,
    stratify=stylegan_df['class'],
    random_state=42
)

# --- Create datasets ---
train_ds_stylegan = load_dataset_from_df(train_df_stylegan, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')
val_ds_stylegan = load_dataset_from_df(val_df_stylegan, "filename", "class", img_size=(128, 128), batch_size=32, color_mode='rgb')
test_ds = load_dataset_from_dir(test_data_path, img_size=(128, 128), batch_size=32, gaussian_blur=False, color_mode='rgb')
# Out:
# Found 1600 validated image filenames belonging to 2 classes.
# Found 400 validated image filenames belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Train and evaluate using synthetic (Style GAn) training data
test_description = "tuned_cnn_vgg_style_gan"

history_stylegan, y_true_stylegan, y_pred_stylegan, results_df_stylegan = train_and_evaluate(
    model=model,
    train_ds=train_ds_stylegan,
    val_ds=val_ds_stylegan,
    test_ds=test_ds,
    test_description=test_description
)

plot_results(history_stylegan, y_true_stylegan, y_pred_stylegan, test_description)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 630s 13s/step - accuracy: 0.9542 - loss: 0.1489 - precision: 0.9495 - recall: 0.9585 - val_accuracy: 0.9725 - val_loss: 0.0651 - val_precision: 0.9701 - val_recall: 0.9750 - learning_rate: 3.0000e-05
# Epoch 2/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 274ms/step - accuracy: 0.9796 - loss: 0.0505 - precision: 0.9740 - recall: 0.9858 - val_accuracy: 0.9825 - val_loss: 0.0412 - val_precision: 0.9754 - val_recall: 0.9900 - learning_rate: 3.0000e-05
# Epoch 3/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 275ms/step - accuracy: 0.9871 - loss: 0.0381 - precision: 0.9857 - recall: 0.9888 - val_accuracy: 0.9850 - val_loss: 0.0384 - val_precision: 0.9755 - val_recall: 0.9950 - learning_rate: 3.0000e-05
# Epoch 4/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 277ms/step - accuracy: 0.9954 - loss: 0.0155 - precision: 0.9956 - recall: 0.9952 - val_accuracy: 0.9975 - val_loss: 0.0231 - val_precision: 0.9950 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Epoch 5/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 272ms/step - accuracy: 0.9942 - loss: 0.0106 - precision: 0.9917 - recall: 0.9970 - val_accuracy: 0.9925 - val_loss: 0.0248 - val_precision: 0.9852 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Epoch 6/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 278ms/step - accuracy: 0.9929 - loss: 0.0197 - precision: 0.9885 - recall: 0.9971 - val_accuracy: 0.9975 - val_loss: 0.0173 - val_precision: 0.9950 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Epoch 7/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 272ms/step - accuracy: 0.9989 - loss: 0.0027 - precision: 0.9989 - recall: 0.9989 - val_accuracy: 0.9925 - val_loss: 0.0107 - val_precision: 0.9950 - val_recall: 0.9900 - learning_rate: 3.0000e-05
# Epoch 8/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 276ms/step - accuracy: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9950 - val_loss: 0.0085 - val_precision: 0.9950 - val_recall: 0.9950 - learning_rate: 3.0000e-05
# Epoch 9/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 274ms/step - accuracy: 1.0000 - loss: 0.0020 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9900 - val_loss: 0.0178 - val_precision: 1.0000 - val_recall: 0.9800 - learning_rate: 3.0000e-05
# Epoch 10/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 274ms/step - accuracy: 1.0000 - loss: 5.2172e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9975 - val_loss: 0.0042 - val_precision: 1.0000 - val_recall: 0.9950 - learning_rate: 3.0000e-05
# Epoch 11/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 278ms/step - accuracy: 0.9995 - loss: 0.0025 - precision: 1.0000 - recall: 0.9991 - val_accuracy: 1.0000 - val_loss: 0.0021 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Epoch 12/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 270ms/step - accuracy: 1.0000 - loss: 9.7602e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9975 - val_loss: 0.0050 - val_precision: 1.0000 - val_recall: 0.9950 - learning_rate: 3.0000e-05
# Epoch 13/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 275ms/step - accuracy: 0.9990 - loss: 0.0011 - precision: 0.9978 - recall: 1.0000 - val_accuracy: 0.9975 - val_loss: 0.0048 - val_precision: 1.0000 - val_recall: 0.9950 - learning_rate: 3.0000e-05
# Epoch 14/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 274ms/step - accuracy: 1.0000 - loss: 3.2552e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9975 - val_loss: 0.0079 - val_precision: 1.0000 - val_recall: 0.9950 - learning_rate: 3.0000e-05
# Epoch 15/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 275ms/step - accuracy: 1.0000 - loss: 1.3904e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0023 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Epoch 16/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 2.0139e-04 - precision: 1.0000 - recall: 1.0000
# Epoch 16: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 13s 267ms/step - accuracy: 1.0000 - loss: 2.0060e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_loss: 0.0022 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 3.0000e-05
# Metrics saved to tuned_cnn_vgg_style_gan_results.csv
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89       234
#            1       0.91      0.96      0.94       390
#
#     accuracy                           0.92       624
#    macro avg       0.92      0.91      0.91       624
# weighted avg       0.92      0.92      0.92       624
