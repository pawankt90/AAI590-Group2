# %%
import os
import random
import numpy as np
import pandas as pd
from data_utils import load_sample_dataframe_from_dir
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 5
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from data_utils import load_sample_dataframe_from_dir
#
# ImportError: cannot import name 'load_sample_dataframe_from_dir' from 'data_utils' (C:\Users\nedko\USD\MS-AAI-590 - Capstone\AAI590-Group2\data_utils.py)

# %%
normal_data_path = '../data/chest_xray/val/NORMAL'
pneumonia_data_path = '../data/chest_xray/val/PNEUMONIA'
df = pd.DataFrame(columns=['filename', 'class'])
val_df = load_sample_dataframe_from_dir(df, data_path, 'NORMAL', 2, 42)
val_df = load_sample_dataframe_from_dir(val_df, data_path, 'PNEUMONIA', 2, 42)
val_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 pneumonia_data_path = '../data/chest_xray/val/PNEUMONIA'
#       3 df = pd.DataFrame(columns=['filename', 'class'])
# ----> 4 val_df = load_sample_dataframe_from_dir(df, data_path, 'NORMAL', 2, 42)
#       5 val_df = load_sample_dataframe_from_dir(val_df, data_path, 'PNEUMONIA', 2, 42)
#       6 val_df
#
# NameError: name 'load_sample_dataframe_from_dir' is not defined
